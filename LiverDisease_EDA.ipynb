# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("project-data.csv", delimiter=";")
df.head()
# Out:
#       category  age sex  albumin  alkaline_phosphatase  \
# 0   no_disease   32   m     38.5                  52.5
# 1   no_disease   32   m     38.5                  70.3
# 2   no_disease   32   m     46.9                  74.7
# 3   no_disease   32   m     43.2                  52.0
# 4   no_disease   32   m     39.2                  74.1
#
#    alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                       7.7                        22.1        7.5
# 1                      18.0                        24.7        3.9
# 2                      36.2                        52.6        6.1
# 3                      30.6                        22.6       18.9
# 4                      32.6                        24.8        9.6
#
#    cholinesterase  cholesterol  creatinina  gamma_glutamyl_transferase   \
# 0            6.93         3.23       106.0                         12.1
# 1           11.17         4.80        74.0                         15.6
# ...

# %%
df.shape
# Out:
# (615, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     615 non-null    object
#  1   age                          615 non-null    int64
#  2   sex                          615 non-null    object
#  3   albumin                      614 non-null    float64
#  4   alkaline_phosphatase         597 non-null    float64
#  5   alanine_aminotransferase     614 non-null    float64
#  6   aspartate_aminotransferase   615 non-null    float64
#  7   bilirubin                    615 non-null    float64
#  8   cholinesterase               615 non-null    float64
#  9   cholesterol                  605 non-null    float64
#  10  creatinina                   615 non-null    float64
#  11  gamma_glutamyl_transferase   615 non-null    float64
# ...

# %%
df.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  614.000000            597.000000                614.000000
# mean    47.408130   41.620195             68.283920                 28.450814
# std     10.055105    5.780629             26.028315                 25.469689
# min     19.000000   14.900000             11.300000                  0.900000
# 25%     39.000000   38.800000             52.500000                 16.400000
# 50%     47.000000   41.950000             66.200000                 23.000000
# 75%     54.000000   45.200000             80.100000                 33.075000
# max     77.000000   82.200000            416.600000                325.300000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   605.000000
# mean                    34.786341   11.396748        8.196634     5.368099
# ...

# %%
df.isnull().sum()
# Out:
# category                        0
# age                             0
# sex                             0
# albumin                         1
# alkaline_phosphatase           18
# alanine_aminotransferase        1
# aspartate_aminotransferase      0
# bilirubin                       0
# cholinesterase                  0
# cholesterol                    10
# creatinina                      0
# gamma_glutamyl_transferase      0
# protein                         0
# dtype: int64

# %%
for column in df.select_dtypes(include=np.number):
  df[column].fillna(df[column].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# category                       0
# age                            0
# sex                            0
# albumin                        0
# alkaline_phosphatase           0
# alanine_aminotransferase       0
# aspartate_aminotransferase     0
# bilirubin                      0
# cholinesterase                 0
# cholesterol                    0
# creatinina                     0
# gamma_glutamyl_transferase     0
# protein                        0
# dtype: int64

# %%
df.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  615.000000            615.000000                615.000000
# mean    47.408130   41.620732             68.222927                 28.441951
# std     10.055105    5.775935             25.646364                 25.449889
# min     19.000000   14.900000             11.300000                  0.900000
# 25%     39.000000   38.800000             52.950000                 16.400000
# 50%     47.000000   41.950000             66.200000                 23.000000
# 75%     54.000000   45.200000             79.300000                 33.050000
# max     77.000000   82.200000            416.600000                325.300000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   615.000000
# mean                    34.786341   11.396748        8.196634     5.366992
# ...

# %%
df.columns
# Out:
# Index(['category', 'age', 'sex', 'albumin', 'alkaline_phosphatase',
#        'alanine_aminotransferase', 'aspartate_aminotransferase', 'bilirubin',
#        'cholinesterase', 'cholesterol', 'creatinina',
#        'gamma_glutamyl_transferase ', 'protein   '],
#       dtype='object')

# %%
df['protein   '] = pd.to_numeric(df['protein   '], errors='coerce')
print(df['protein   '].head())
# Out:
# 0    69.0
# 1    76.5
# 2    79.3
# 3    75.7
# 4    68.7
# Name: protein   , dtype: float64

# %%
df['category'].value_counts()
# Out:
#  no_disease        533
#  cirrhosis          30
#  hepatitis          24
#  fibrosis           21
# suspect_disease      7
# Name: category, dtype: int64

# %%
for column in df.select_dtypes(include=['object']):
  print(f"Column: {column}")
  print(df[column].value_counts())
  print("-------------------")
# Out:
# Column: category
#  no_disease        533
#  cirrhosis          30
#  hepatitis          24
#  fibrosis           21
# suspect_disease      7
# Name: category, dtype: int64
# -------------------
# Column: sex
# m    377
# f    238
# Name: sex, dtype: int64
# -------------------

# %%
for column in df.select_dtypes(include=['object']):
  plt.figure(figsize=(8, 5))
  sns.countplot(x=column, data=df)
  plt.title(f"Distribution of {column}")
  plt.xticks(rotation=45, ha='right')
  plt.show()

# %%
df.hist(figsize=(15, 10))
plt.show()

# %%
for column in df.select_dtypes(include=np.number):
  plt.figure(figsize=(8, 5))
  sns.distplot(x=df[column])
  plt.title(column)
  plt.show()
# Out:
# <ipython-input-16-d907749394d6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[column])
# <ipython-input-16-d907749394d6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[column])
# <ipython-input-16-d907749394d6>:3: UserWarning:
#
# ...

# %%
for column in df.select_dtypes(include=np.number):
  plt.figure(figsize=(8, 4))
  sns.boxplot(x=df[column])
  plt.title(column)
  plt.show()

# %%
num_df = df.select_dtypes(include=['float64', 'int64'])
num_df.corr()
# Out:
#                                   age   albumin  alkaline_phosphatase  \
# age                          1.000000 -0.196842              0.168080
# albumin                     -0.196842  1.000000             -0.138015
# alkaline_phosphatase         0.168080 -0.138015              1.000000
# alanine_aminotransferase    -0.005690  0.001444              0.166320
# aspartate_aminotransferase   0.088666 -0.193342              0.059637
# bilirubin                    0.032492 -0.221641              0.046780
# cholinesterase              -0.075093  0.375817              0.033750
# cholesterol                  0.123789  0.204731              0.123197
# creatinina                  -0.022296 -0.001594              0.149831
# gamma_glutamyl_transferase   0.153087 -0.155440              0.440012
# protein                     -0.153668  0.556549             -0.055865
#
#                              alanine_aminotransferase  \
# age                                         -0.005690
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
def handle_outliers(df, target_column):
    num_cols = df.select_dtypes(include=np.number).columns

    for col in num_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Cap outliers instead of removing them
        df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
        df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])
    return df

df = handle_outliers(df, 'category')

# %%
for column in df.select_dtypes(include=np.number):
  plt.figure(figsize=(8, 4))
  sns.boxplot(x=df[column])
  plt.title(column)
  plt.show()

# %%
df.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  615.000000            615.000000                615.000000
# mean    47.407317   41.703008             67.283984                 25.860163
# std     10.052729    4.987365             19.779375                 13.500313
# min     19.000000   29.200000             13.425000                  0.900000
# 25%     39.000000   38.800000             52.950000                 16.400000
# 50%     47.000000   41.950000             66.200000                 23.000000
# 75%     54.000000   45.200000             79.300000                 33.050000
# max     76.500000   54.800000            118.825000                 58.025000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   615.000000
# mean                    28.668130    8.879431        8.202309     5.358667
# ...

# %%
pd.crosstab(df['sex'] , df['category'] , margins= True , margins_name = 'Total')
# Out:
# category   cirrhosis   fibrosis   hepatitis   no_disease  suspect_disease  \
# sex
# f                 10          8           4          215                1
# m                 20         13          20          318                6
# Total             30         21          24          533                7
#
# category  Total
# sex
# f           238
# m           377
# Total       615

# %%
bins = [-1, 40, 60, float('inf')]
labels = ['< 40', '40 to 60', '> 60']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
pd.crosstab(df['age_group'] , df['category'] , margins= True , margins_name = 'Total')
# Out:
# category    cirrhosis   fibrosis   hepatitis   no_disease  suspect_disease  \
# age_group
# < 40                2          4          14          154                0
# 40 to 60           22         13           9          329                5
# > 60                6          4           1           50                2
# Total              30         21          24          533                7
#
# category   Total
# age_group
# < 40         174
# 40 to 60     378
# > 60          63
# Total        615

# %%
plt.figure(figsize = ( 12, 18))
for i in enumerate(num_df):
    plt.subplot( 7,2,i[0]+1)
    sns.boxplot(x='category', y= df[i[1]], data=df)
    plt.title(f"Boxplot for {i[1]}." , fontsize = 8)
    plt.xticks(fontsize = 6)

plt.subplots_adjust(wspace= 0.5, hspace = 0.5)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False)

# %%
cat_col = ['sex']
encoded_col = ohe.fit_transform(df[cat_col])

# %%
encoded_df = pd.DataFrame(encoded_col, columns=ohe.get_feature_names_out(cat_col))
df_encoded = pd.concat([df.drop(columns=cat_col), encoded_df], axis=1)

df_encoded.head()
# Out:
#       category   age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0   no_disease  32.0     38.5                  52.5                       7.7
# 1   no_disease  32.0     38.5                  70.3                      18.0
# 2   no_disease  32.0     46.9                  74.7                      36.2
# 3   no_disease  32.0     43.2                  52.0                      30.6
# 4   no_disease  32.0     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                       22.10        7.5            6.93         3.23
# 1                       24.70        3.9           11.17         4.80
# 2                       49.85        6.1            8.84         5.20
# 3                       22.60       18.9            7.33         4.74
# 4                       24.80        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase   protein    age_group  sex_m
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     615 non-null    object
#  1   age                          615 non-null    float64
#  2   albumin                      615 non-null    float64
#  3   alkaline_phosphatase         615 non-null    float64
#  4   alanine_aminotransferase     615 non-null    float64
#  5   aspartate_aminotransferase   615 non-null    float64
#  6   bilirubin                    615 non-null    float64
#  7   cholinesterase               615 non-null    float64
#  8   cholesterol                  615 non-null    float64
#  9   creatinina                   615 non-null    float64
#  10  gamma_glutamyl_transferase   615 non-null    float64
#  11  protein                      614 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_encoded.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
le = LabelEncoder()
df_encoded['category'] = le.fit_transform(df_encoded['category'])
df_encoded.head()
# Out:
#    category   age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0         3  32.0     38.5                  52.5                       7.7
# 1         3  32.0     38.5                  70.3                      18.0
# 2         3  32.0     46.9                  74.7                      36.2
# 3         3  32.0     43.2                  52.0                      30.6
# 4         3  32.0     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                       22.10        7.5            6.93         3.23
# 1                       24.70        3.9           11.17         4.80
# 2                       49.85        6.1            8.84         5.20
# 3                       22.60       18.9            7.33         4.74
# 4                       24.80        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase   protein    age_group  sex_m
# ...

# %%
df_encoded['category'].unique()
# Out:
# array([3, 4, 2, 1, 0])

# %%
df1 = df_encoded.copy()

# %%
df1.head()
# Out:
#    category   age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0         3  32.0     38.5                  52.5                       7.7
# 1         3  32.0     38.5                  70.3                      18.0
# 2         3  32.0     46.9                  74.7                      36.2
# 3         3  32.0     43.2                  52.0                      30.6
# 4         3  32.0     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                       22.10        7.5            6.93         3.23
# 1                       24.70        3.9           11.17         4.80
# 2                       49.85        6.1            8.84         5.20
# 3                       22.60       18.9            7.33         4.74
# 4                       24.80        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase   protein    age_group  sex_m
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     615 non-null    int64
#  1   age                          615 non-null    float64
#  2   albumin                      615 non-null    float64
#  3   alkaline_phosphatase         615 non-null    float64
#  4   alanine_aminotransferase     615 non-null    float64
#  5   aspartate_aminotransferase   615 non-null    float64
#  6   bilirubin                    615 non-null    float64
#  7   cholinesterase               615 non-null    float64
#  8   cholesterol                  615 non-null    float64
#  9   creatinina                   615 non-null    float64
#  10  gamma_glutamyl_transferase   615 non-null    float64
#  11  protein                      614 non-null    float64
# ...

# %%
df1.drop(columns=['age_group'], inplace=True)

# %%
df1.head()
# Out:
#    category   age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0         3  32.0     38.5                  52.5                       7.7
# 1         3  32.0     38.5                  70.3                      18.0
# 2         3  32.0     46.9                  74.7                      36.2
# 3         3  32.0     43.2                  52.0                      30.6
# 4         3  32.0     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                       22.10        7.5            6.93         3.23
# 1                       24.70        3.9           11.17         4.80
# 2                       49.85        6.1            8.84         5.20
# 3                       22.60       18.9            7.33         4.74
# 4                       24.80        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase   protein     sex_m
# ...

# %%
# !pip install ppscore

# %%
import ppscore as pps

# %%
x = df.iloc[:, 1:13]

# %%
pps_matrix = pps.matrix(df1)
pps_matrix
# Out:
#             x                            y   ppscore            case  \
# 0    category                     category  1.000000  predict_itself
# 1    category                          age  0.015908      regression
# 2    category                      albumin  0.077997      regression
# 3    category         alkaline_phosphatase  0.021921      regression
# 4    category     alanine_aminotransferase  0.000000      regression
# ..        ...                          ...       ...             ...
# 164     sex_m                  cholesterol  0.000000      regression
# 165     sex_m                   creatinina  0.159632      regression
# 166     sex_m  gamma_glutamyl_transferase   0.000000      regression
# 167     sex_m                   protein     0.000000      regression
# 168     sex_m                        sex_m  1.000000  predict_itself
#
#      is_valid_score               metric  baseline_score  model_score  \
# ...

# %%
pps_matrix[['x','y','ppscore']][pps_matrix['y'] == 'category'].sort_values(by = 'ppscore', ascending = False)
# Out:
#                                x         y   ppscore
# 0                       category  category  1.000000
# 65    aspartate_aminotransferase  category  0.089820
# 78                     bilirubin  category  0.030468
# 13                           age  category  0.000000
# 26                       albumin  category  0.000000
# 39          alkaline_phosphatase  category  0.000000
# 52      alanine_aminotransferase  category  0.000000
# 91                cholinesterase  category  0.000000
# 104                  cholesterol  category  0.000000
# 117                   creatinina  category  0.000000
# 130  gamma_glutamyl_transferase   category  0.000000
# 143                   protein     category  0.000000
# 156                        sex_m  category  0.000000

# %%
sns.scatterplot( data = df1 , x = 'aspartate_aminotransferase' , y = 'albumin' , hue = 'category', palette='viridis' )
# Out:
# <Axes: xlabel='aspartate_aminotransferase', ylabel='albumin'>

# %%
sns.scatterplot( data = df1 , y = 'bilirubin' , x = 'albumin' , hue = 'category', palette='viridis')
# Out:
# <Axes: xlabel='albumin', ylabel='bilirubin'>

# %%
df1.head()
# Out:
#    category   age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0         3  32.0     38.5                  52.5                       7.7
# 1         3  32.0     38.5                  70.3                      18.0
# 2         3  32.0     46.9                  74.7                      36.2
# 3         3  32.0     43.2                  52.0                      30.6
# 4         3  32.0     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                       22.10        7.5            6.93         3.23
# 1                       24.70        3.9           11.17         4.80
# 2                       49.85        6.1            8.84         5.20
# 3                       22.60       18.9            7.33         4.74
# 4                       24.80        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase   protein     sex_m
# ...

# %%
x = df1.drop(columns=['category'])
y = df1['category']

# %%
x.head()
# Out:
#     age  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0  32.0     38.5                  52.5                       7.7
# 1  32.0     38.5                  70.3                      18.0
# 2  32.0     46.9                  74.7                      36.2
# 3  32.0     43.2                  52.0                      30.6
# 4  32.0     39.2                  74.1                      32.6
#
#    aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# 0                       22.10        7.5            6.93         3.23
# 1                       24.70        3.9           11.17         4.80
# 2                       49.85        6.1            8.84         5.20
# 3                       22.60       18.9            7.33         4.74
# 4                       24.80        9.6            9.15         4.32
#
#    creatinina  gamma_glutamyl_transferase   protein     sex_m
# 0       106.0                         12.1        69.0    1.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((492, 12), (123, 12), (492,), (123,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(oob_score=True)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(oob_score=True)

# %%
model.oob_score_
# Out:
# 0.9349593495934959

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8780487804878049

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 7,  1,  0,  1,  0],
#        [ 0,  2,  0,  4,  0],
#        [ 0,  1,  3,  5,  0],
#        [ 0,  0,  0, 96,  0],
#        [ 0,  0,  0,  3,  0]])

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88         9
#            1       0.50      0.33      0.40         6
#            2       1.00      0.33      0.50         9
#            3       0.88      1.00      0.94        96
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.88       123
#    macro avg       0.68      0.49      0.54       123
# weighted avg       0.86      0.88      0.85       123
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# %%
imputer.fit(x_train)
# Out:
# SimpleImputer()

# %%
x_train = imputer.transform(x_train)
x_test = imputer.transform(x_test)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='linear')
svc.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred1 = svc.predict(x_test)

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.8536585365853658
